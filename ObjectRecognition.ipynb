# %% [markdown]
# ## Object recognition with YOLO ##

# %%
import os
import torch
import cv2
import pandas as pd
from ultralytics import YOLO
import matplotlib.pyplot as plt


def get_folder_path(prompt, create_if_missing=False):
    while True:
        path = input(prompt).strip()
        if path:
            if os.path.exists(path) or create_if_missing:
                os.makedirs(path, exist_ok=True)  # Create folder if missing
                print(f"✅ Using folder: {path}")
                return path
        print("❌ Invalid or empty path. Please enter a valid folder path.")

# Function to list available folders before selection
def list_available_folders(base_path):
    print("📂 Available folders:")
    folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]
    if not folders:
        print("❌ No folders found. Exiting.")
        exit()
    for idx, folder in enumerate(folders, start=1):
        print(f"{idx}. {folder}")
    return folders

# Load YOLO model (using YOLOv8 pretrained model)
def load_yolo_model():
    print("🔄 Loading YOLOv8 model...")
    model = YOLO("yolov8n.pt") 
    print("✅ YOLO model loaded successfully!")
    return model

# Perform object detection on an image
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform detection
    detections = []
    
    for result in results:
        for box in result.boxes.data:
            x1, y1, x2, y2, conf, cls = box.tolist()
            detections.append({
                "image": os.path.basename(image_path),
                "class": model.names[int(cls)],
                "confidence": round(conf, 2),
                "bbox": [int(x1), int(y1), int(x2), int(y2)]
            })
    return detections

# Visualize detections and save annotated images
def visualize_and_save(image_path, detections, output_folder):
    image = cv2.imread(image_path)
    for det in detections:
        x1, y1, x2, y2 = det["bbox"]
        label = f"{det['class']} ({det['confidence']})"
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    output_path = os.path.join(output_folder, os.path.basename(image_path))
    cv2.imwrite(output_path, image)
    print(f"✅ Saved annotated image: {output_path}")

# Function to manually select which movies to process
def select_movies(movies):
    print("📂 Available movie folders:")
    for idx, movie in enumerate(movies, start=1):
        print(f"{idx}. {movie}")
    
    selected_indices = input("Enter the numbers of the movies you want to analyze (comma-separated, e.g., 1,3,5): ")
    selected_indices = [int(i.strip()) - 1 for i in selected_indices.split(',') if i.strip().isdigit() and 0 <= int(i.strip()) - 1 < len(movies)]
    
    if not selected_indices:
        print("❌ No valid selections made. Exiting.")
        exit()
    
    selected_movies = [movies[i] for i in selected_indices]
    return selected_movies

# Function to process all selected movies
def process_selected_movies(model, keyframe_base_folder, output_image_folder):
    movies = list_available_folders(keyframe_base_folder)
    selected_movies = select_movies(movies)
    
    for movie in selected_movies:
        movie_path = os.path.join(keyframe_base_folder, movie)
        output_csv = os.path.join(keyframe_base_folder, f"object_detection_results_{movie}.csv")  # Unique CSV for each movie
        detections_list = []
        
        print(f"📂 Processing keyframes from movie: {movie}")
        keyframe_images = [f for f in os.listdir(movie_path) if f.endswith(".jpg")]
        for img in keyframe_images:
            img_path = os.path.join(movie_path, img)
            detections = detect_objects(model, img_path)
            detections_list.extend(detections)
            visualize_and_save(img_path, detections, output_image_folder)
        
        # Save detections to unique CSV for each movie
        df = pd.DataFrame(detections_list)
        df.to_csv(output_csv, index=False)
        print(f"✅ Object detection results saved to {output_csv}")


if __name__ == "__main__":
    keyframe_base_folder = get_folder_path("Enter the base folder containing movie keyframes: ")
    output_image_folder = get_folder_path("Enter the folder to save annotated images: ", create_if_missing=True)
    
    yolo_model = load_yolo_model()
    process_selected_movies(yolo_model, keyframe_base_folder, output_image_folder)
    
    print("✅ Object detection process completed!")
# Out:
# ✅ Using folder: /Users/alicja/Desktop/VideoAnalyse/Corpus/KeyFrames/DramaKeyframes
# ✅ Using folder: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05
# 🔄 Loading YOLOv8 model...
# ✅ YOLO model loaded successfully!
# 📂 Available folders:
# 1. Drama_04
# 2. Drama_03
# 3. Drama_02
# 4. Drama_05
# 5. Drama_01
# 📂 Available movie folders:
# 1. Drama_04
# 2. Drama_03
# 3. Drama_02
# 4. Drama_05
# 5. Drama_01
# 📂 Processing keyframes from movie: Drama_05
#
# 0: 416x640 1 person, 1 tie, 2 wine glasss, 70.0ms
# Speed: 3.5ms preprocess, 70.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_35_keyframe.jpg
#
# 0: 416x640 1 person, 59.0ms
# Speed: 2.2ms preprocess, 59.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_60_keyframe.jpg
#
# 0: 416x640 2 persons, 69.3ms
# Speed: 2.3ms preprocess, 69.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_140_keyframe.jpg
#
# 0: 416x640 3 persons, 83.7ms
# Speed: 3.6ms preprocess, 83.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_115_keyframe.jpg
#
# 0: 416x640 3 persons, 87.7ms
# Speed: 4.7ms preprocess, 87.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_98_keyframe.jpg
#
# 0: 416x640 4 persons, 1 tie, 1 wine glass, 1 cup, 87.4ms
# Speed: 6.6ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_32_keyframe.jpg
#
# 0: 416x640 2 persons, 1 tie, 69.6ms
# Speed: 4.0ms preprocess, 69.6ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_67_keyframe.jpg
#
# 0: 416x640 1 person, 60.6ms
# Speed: 2.8ms preprocess, 60.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_147_keyframe.jpg
#
# 0: 416x640 8 persons, 69.7ms
# Speed: 2.6ms preprocess, 69.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_112_keyframe.jpg
#
# 0: 416x640 2 persons, 1 dog, 2 horses, 67.4ms
# Speed: 3.2ms preprocess, 67.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_358_keyframe.jpg
#
# 0: 416x640 1 person, 80.3ms
# Speed: 5.1ms preprocess, 80.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_285_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 64.0ms
# Speed: 3.9ms preprocess, 64.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_152_keyframe.jpg
#
# 0: 416x640 (no detections), 64.6ms
# Speed: 3.8ms preprocess, 64.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_107_keyframe.jpg
#
# 0: 416x640 2 persons, 64.6ms
# Speed: 3.8ms preprocess, 64.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_27_keyframe.jpg
#
# 0: 416x640 1 person, 72.3ms
# Speed: 3.1ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_72_keyframe.jpg
#
# 0: 416x640 1 person, 70.8ms
# Speed: 4.3ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_155_keyframe.jpg
#
# 0: 416x640 (no detections), 68.6ms
# Speed: 2.6ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_100_keyframe.jpg
#
# 0: 416x640 1 person, 1 surfboard, 66.9ms
# Speed: 4.5ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_20_keyframe.jpg
#
# 0: 416x640 1 person, 67.1ms
# Speed: 2.2ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_75_keyframe.jpg
#
# 0: 416x640 1 person, 1 horse, 66.6ms
# Speed: 2.7ms preprocess, 66.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_297_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 66.5ms
# Speed: 4.1ms preprocess, 66.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_290_keyframe.jpg
#
# 0: 416x640 8 persons, 126.8ms
# Speed: 3.9ms preprocess, 126.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_318_keyframe.jpg
#
# 0: 416x640 4 persons, 75.8ms
# Speed: 3.3ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_16_keyframe.jpg
#
# 0: 416x640 1 person, 72.8ms
# Speed: 3.1ms preprocess, 72.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_43_keyframe.jpg
#
# 0: 416x640 2 persons, 63.8ms
# Speed: 2.7ms preprocess, 63.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_163_keyframe.jpg
#
# 0: 416x640 1 person, 1 horse, 65.7ms
# Speed: 2.5ms preprocess, 65.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_11_keyframe.jpg
#
# 0: 416x640 1 person, 66.7ms
# Speed: 2.9ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_44_keyframe.jpg
#
# 0: 416x640 3 persons, 68.4ms
# Speed: 4.4ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_164_keyframe.jpg
#
# 0: 416x640 6 persons, 1 cell phone, 68.5ms
# Speed: 2.8ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_131_keyframe.jpg
#
# 0: 416x640 1 person, 67.0ms
# Speed: 4.6ms preprocess, 67.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_259_keyframe.jpg
#
# 0: 416x640 1 person, 60.7ms
# Speed: 3.2ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_384_keyframe.jpg
#
# 0: 416x640 3 persons, 2 ties, 4 wine glasss, 67.0ms
# Speed: 2.5ms preprocess, 67.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_329_keyframe.jpg
#
# 0: 416x640 1 person, 70.5ms
# Speed: 3.3ms preprocess, 70.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_383_keyframe.jpg
#
# 0: 416x640 4 persons, 65.7ms
# Speed: 2.7ms preprocess, 65.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_171_keyframe.jpg
#
# 0: 416x640 5 persons, 3 chairs, 1 dining table, 84.1ms
# Speed: 2.9ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_124_keyframe.jpg
#
# 0: 416x640 3 persons, 1 pizza, 70.4ms
# Speed: 4.3ms preprocess, 70.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_51_keyframe.jpg
#
# 0: 416x640 3 persons, 1 orange, 82.6ms
# Speed: 2.6ms preprocess, 82.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_176_keyframe.jpg
#
# 0: 416x640 1 person, 109.6ms
# Speed: 3.3ms preprocess, 109.6ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_123_keyframe.jpg
#
# 0: 416x640 9 persons, 1 tie, 1 wine glass, 67.8ms
# Speed: 3.1ms preprocess, 67.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_189_keyframe.jpg
#
# 0: 416x640 1 bed, 66.3ms
# Speed: 4.1ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_369_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 63.8ms
# Speed: 3.4ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_396_keyframe.jpg
#
# 0: 416x640 1 person, 65.5ms
# Speed: 3.3ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_7_keyframe.jpg
#
# 0: 416x640 2 persons, 1 horse, 2 ties, 63.5ms
# Speed: 4.4ms preprocess, 63.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_391_keyframe.jpg
#
# 0: 416x640 3 persons, 1 toothbrush, 71.5ms
# Speed: 2.9ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_219_keyframe.jpg
#
# 0: 416x640 2 persons, 66.5ms
# Speed: 3.3ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_101_keyframe.jpg
#
# 0: 416x640 2 persons, 1 tie, 66.8ms
# Speed: 3.0ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_154_keyframe.jpg
#
# 0: 416x640 1 person, 65.8ms
# Speed: 3.4ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_74_keyframe.jpg
#
# 0: 416x640 4 persons, 1 tie, 4 wine glasss, 1 cup, 66.6ms
# Speed: 3.9ms preprocess, 66.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_21_keyframe.jpg
#
# 0: 416x640 1 person, 67.6ms
# Speed: 2.7ms preprocess, 67.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_106_keyframe.jpg
#
# 0: 416x640 1 person, 66.5ms
# Speed: 4.5ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_153_keyframe.jpg
#
# 0: 416x640 2 persons, 1 tie, 62.6ms
# Speed: 2.5ms preprocess, 62.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_73_keyframe.jpg
#
# 0: 416x640 3 persons, 1 dog, 1 bear, 62.9ms
# Speed: 4.2ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_319_keyframe.jpg
#
# 0: 416x640 2 persons, 2 suitcases, 66.9ms
# Speed: 4.9ms preprocess, 66.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_291_keyframe.jpg
#
# 0: 416x640 1 person, 1 horse, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_296_keyframe.jpg
#
# 0: 416x640 1 person, 69.3ms
# Speed: 2.4ms preprocess, 69.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_269_keyframe.jpg
#
# 0: 416x640 1 person, 63.2ms
# Speed: 4.0ms preprocess, 63.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_66_keyframe.jpg
#
# 0: 416x640 3 persons, 1 vase, 66.8ms
# Speed: 2.2ms preprocess, 66.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_33_keyframe.jpg
#
# 0: 416x640 5 persons, 2 ties, 62.9ms
# Speed: 3.3ms preprocess, 62.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_99_keyframe.jpg
#
# 0: 416x640 2 persons, 1 cake, 78.8ms
# Speed: 3.4ms preprocess, 78.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_113_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 66.7ms
# Speed: 4.3ms preprocess, 66.7ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_146_keyframe.jpg
#
# 0: 416x640 1 person, 3 birds, 116.9ms
# Speed: 3.4ms preprocess, 116.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_34_keyframe.jpg
#
# 0: 416x640 2 persons, 1 cup, 65.1ms
# Speed: 3.4ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_114_keyframe.jpg
#
# 0: 416x640 1 person, 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_141_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 67.6ms
# Speed: 4.6ms preprocess, 67.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_283_keyframe.jpg
#
# 0: 416x640 1 person, 62.9ms
# Speed: 3.9ms preprocess, 62.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_229_keyframe.jpg
#
# 0: 416x640 1 person, 65.5ms
# Speed: 2.5ms preprocess, 65.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_284_keyframe.jpg
#
# 0: 416x640 1 person, 1 suitcase, 63.9ms
# Speed: 3.8ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_359_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 77.0ms
# Speed: 2.9ms preprocess, 77.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_188_keyframe.jpg
#
# 0: 416x640 2 persons, 71.3ms
# Speed: 3.6ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_122_keyframe.jpg
#
# 0: 416x640 10 persons, 4 chairs, 93.7ms
# Speed: 3.4ms preprocess, 93.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_177_keyframe.jpg
#
# 0: 416x640 2 persons, 1 tie, 139.2ms
# Speed: 4.2ms preprocess, 139.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_57_keyframe.jpg
#
# 0: 416x640 3 persons, 75.1ms
# Speed: 3.7ms preprocess, 75.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_50_keyframe.jpg
#
# 0: 416x640 2 persons, 63.9ms
# Speed: 3.7ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_1_keyframe.jpg
#
# 0: 416x640 2 persons, 65.9ms
# Speed: 3.2ms preprocess, 65.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_218_keyframe.jpg
#
# 0: 416x640 1 person, 1 frisbee, 67.9ms
# Speed: 3.6ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_390_keyframe.jpg
#
# 0: 416x640 1 person, 71.5ms
# Speed: 3.3ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_6_keyframe.jpg
#
# 0: 416x640 1 person, 68.0ms
# Speed: 2.9ms preprocess, 68.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_397_keyframe.jpg
#
# 0: 416x640 3 persons, 2 umbrellas, 1 chair, 1 potted plant, 69.5ms
# Speed: 3.6ms preprocess, 69.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_368_keyframe.jpg
#
# 0: 416x640 1 person, 2 horses, 66.7ms
# Speed: 3.2ms preprocess, 66.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_10_keyframe.jpg
#
# 0: 416x640 1 person, 64.1ms
# Speed: 2.8ms preprocess, 64.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_130_keyframe.jpg
#
# 0: 416x640 4 persons, 75.0ms
# Speed: 44.9ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_165_keyframe.jpg
#
# 0: 416x640 1 person, 84.8ms
# Speed: 3.3ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_42_keyframe.jpg
#
# 0: 416x640 3 persons, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_17_keyframe.jpg
#
# 0: 416x640 4 persons, 1 chair, 65.1ms
# Speed: 3.4ms preprocess, 65.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_137_keyframe.jpg
#
# 0: 416x640 (no detections), 64.2ms
# Speed: 3.4ms preprocess, 64.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_162_keyframe.jpg
#
# 0: 416x640 1 person, 66.5ms
# Speed: 3.5ms preprocess, 66.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_382_keyframe.jpg
#
# 0: 416x640 1 person, 68.7ms
# Speed: 2.8ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_385_keyframe.jpg
#
# 0: 416x640 2 persons, 62.2ms
# Speed: 2.6ms preprocess, 62.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_258_keyframe.jpg
#
# 0: 416x640 2 persons, 80.1ms
# Speed: 3.6ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_168_keyframe.jpg
#
# 0: 416x640 2 persons, 73.4ms
# Speed: 2.3ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_197_keyframe.jpg
#
# 0: 416x640 (no detections), 66.0ms
# Speed: 3.3ms preprocess, 66.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_190_keyframe.jpg
#
# 0: 416x640 3 persons, 68.7ms
# Speed: 2.8ms preprocess, 68.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_207_keyframe.jpg
#
# 0: 416x640 4 persons, 1 bowl, 66.7ms
# Speed: 2.6ms preprocess, 66.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_370_keyframe.jpg
#
# 0: 416x640 1 person, 65.7ms
# Speed: 2.6ms preprocess, 65.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_325_keyframe.jpg
#
# 0: 416x640 1 person, 1 clock, 71.3ms
# Speed: 2.6ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_401_keyframe.jpg
#
# 0: 416x640 (no detections), 69.1ms
# Speed: 2.3ms preprocess, 69.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_255_keyframe.jpg
#
# 0: 416x640 7 persons, 65.3ms
# Speed: 3.7ms preprocess, 65.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_200_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 71.0ms
# Speed: 3.1ms preprocess, 71.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_377_keyframe.jpg
#
# 0: 416x640 2 persons, 66.9ms
# Speed: 3.4ms preprocess, 66.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_322_keyframe.jpg
#
# 0: 416x640 3 persons, 1 tie, 71.7ms
# Speed: 3.6ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_388_keyframe.jpg
#
# 0: 416x640 1 person, 121.5ms
# Speed: 3.1ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_406_keyframe.jpg
#
# 0: 416x640 12 persons, 3 ties, 3 wine glasss, 1 bowl, 1 dining table, 1 vase, 91.6ms
# Speed: 3.2ms preprocess, 91.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_185_keyframe.jpg
#
# 0: 416x640 2 persons, 1 umbrella, 1 cup, 67.0ms
# Speed: 3.3ms preprocess, 67.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_128_keyframe.jpg
#
# 0: 416x640 8 persons, 2 cups, 2 cakes, 1 dining table, 1 vase, 63.0ms
# Speed: 3.4ms preprocess, 63.0ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_182_keyframe.jpg
#
# 0: 416x640 2 persons, 2 bottles, 1 chair, 83.8ms
# Speed: 2.4ms preprocess, 83.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_362_keyframe.jpg
#
# 0: 416x640 2 persons, 86.5ms
# Speed: 2.9ms preprocess, 86.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_337_keyframe.jpg
#
# 0: 416x640 1 person, 63.8ms
# Speed: 3.6ms preprocess, 63.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_240_keyframe.jpg
#
# 0: 416x640 4 persons, 1 tie, 65.8ms
# Speed: 2.6ms preprocess, 65.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_215_keyframe.jpg
#
# 0: 416x640 1 person, 68.0ms
# Speed: 3.3ms preprocess, 68.0ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_365_keyframe.jpg
#
# 0: 416x640 17 persons, 1 dog, 1 tie, 65.5ms
# Speed: 2.8ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_330_keyframe.jpg
#
# 0: 416x640 1 person, 64.3ms
# Speed: 3.9ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_212_keyframe.jpg
#
# 0: 416x640 6 persons, 1 tie, 73.6ms
# Speed: 2.5ms preprocess, 73.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_94_keyframe.jpg
#
# 0: 416x640 10 persons, 1 boat, 1 bird, 69.6ms
# Speed: 4.0ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_119_keyframe.jpg
#
# 0: 416x640 4 persons, 70.6ms
# Speed: 3.5ms preprocess, 70.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_93_keyframe.jpg
#
# 0: 416x640 1 person, 2 ties, 67.0ms
# Speed: 3.3ms preprocess, 67.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_39_keyframe.jpg
#
# 0: 416x640 5 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_353_keyframe.jpg
#
# 0: 416x640 1 person, 63.8ms
# Speed: 2.9ms preprocess, 63.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_306_keyframe.jpg
#
# 0: 416x640 2 persons, 82.3ms
# Speed: 3.4ms preprocess, 82.3ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_271_keyframe.jpg
#
# 0: 416x640 1 chair, 71.3ms
# Speed: 2.7ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_354_keyframe.jpg
#
# 0: 416x640 1 person, 113.0ms
# Speed: 3.6ms preprocess, 113.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_301_keyframe.jpg
#
# 0: 416x640 4 persons, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_276_keyframe.jpg
#
# 0: 416x640 2 persons, 70.8ms
# Speed: 3.2ms preprocess, 70.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_223_keyframe.jpg
#
# 0: 416x640 1 person, 1 donut, 1 chair, 66.3ms
# Speed: 3.5ms preprocess, 66.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_289_keyframe.jpg
#
# 0: 416x640 3 persons, 1 wine glass, 1 vase, 72.9ms
# Speed: 2.3ms preprocess, 72.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_86_keyframe.jpg
#
# 0: 416x640 3 persons, 2 ties, 1 cup, 4 chairs, 1 clock, 1 vase, 68.4ms
# Speed: 4.9ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_79_keyframe.jpg
#
# 0: 416x640 1 person, 66.8ms
# Speed: 3.2ms preprocess, 66.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_159_keyframe.jpg
#
# 0: 416x640 (no detections), 66.8ms
# Speed: 2.6ms preprocess, 66.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_81_keyframe.jpg
#
# 0: 416x640 2 persons, 1 tie, 68.0ms
# Speed: 2.4ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_263_keyframe.jpg
#
# 0: 416x640 2 persons, 77.9ms
# Speed: 2.6ms preprocess, 77.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_236_keyframe.jpg
#
# 0: 416x640 1 person, 73.5ms
# Speed: 3.4ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_341_keyframe.jpg
#
# 0: 416x640 4 persons, 67.6ms
# Speed: 4.5ms preprocess, 67.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_264_keyframe.jpg
#
# 0: 416x640 1 person, 70.0ms
# Speed: 3.3ms preprocess, 70.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_231_keyframe.jpg
#
# 0: 416x640 1 person, 67.7ms
# Speed: 5.3ms preprocess, 67.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_346_keyframe.jpg
#
# 0: 416x640 4 persons, 65.7ms
# Speed: 2.8ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_313_keyframe.jpg
#
# 0: 416x640 1 person, 1 vase, 65.4ms
# Speed: 3.3ms preprocess, 65.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_183_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 69.3ms
# Speed: 2.9ms preprocess, 69.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_129_keyframe.jpg
#
# 0: 416x640 8 persons, 1 chair, 1 potted plant, 1 dining table, 1 vase, 67.4ms
# Speed: 3.6ms preprocess, 67.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_184_keyframe.jpg
#
# 0: 416x640 2 persons, 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_213_keyframe.jpg
#
# 0: 416x640 (no detections), 64.6ms
# Speed: 4.2ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_246_keyframe.jpg
#
# 0: 416x640 3 persons, 71.5ms
# Speed: 44.1ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_331_keyframe.jpg
#
# 0: 416x640 4 persons, 67.1ms
# Speed: 3.8ms preprocess, 67.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_364_keyframe.jpg
#
# 0: 416x640 1 person, 2 horses, 67.3ms
# Speed: 4.4ms preprocess, 67.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_241_keyframe.jpg
#
# 0: 416x640 (no detections), 69.1ms
# Speed: 3.5ms preprocess, 69.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_412_keyframe.jpg
#
# 0: 416x640 1 person, 82.2ms
# Speed: 2.3ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_336_keyframe.jpg
#
# 0: 416x640 6 persons, 68.9ms
# Speed: 2.4ms preprocess, 68.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_363_keyframe.jpg
#
# 0: 416x640 1 person, 1 umbrella, 69.3ms
# Speed: 3.6ms preprocess, 69.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ...
#
# 0: 416x640 1 person, 1 tie, 76.6ms
# Speed: 3.2ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_12_keyframe.jpg
#
# 0: 416x640 3 persons, 1 tie, 69.8ms
# Speed: 3.8ms preprocess, 69.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_47_keyframe.jpg
#
# 0: 416x640 2 persons, 1 umbrella, 2 ties, 94.5ms
# Speed: 2.6ms preprocess, 94.5ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_198_keyframe.jpg
#
# 0: 416x640 1 person, 87.9ms
# Speed: 4.4ms preprocess, 87.9ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_167_keyframe.jpg
#
# 0: 416x640 5 persons, 95.1ms
# Speed: 3.4ms preprocess, 95.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_132_keyframe.jpg
#
# 0: 416x640 1 person, 1 cell phone, 94.1ms
# Speed: 4.6ms preprocess, 94.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_280_keyframe.jpg
#
# 0: 416x640 (no detections), 96.3ms
# Speed: 4.2ms preprocess, 96.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_308_keyframe.jpg
#
# 0: 416x640 3 persons, 76.8ms
# Speed: 5.4ms preprocess, 76.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_278_keyframe.jpg
#
# 0: 416x640 1 person, 75.2ms
# Speed: 3.1ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_287_keyframe.jpg
#
# 0: 416x640 3 persons, 1 truck, 3 bottles, 83.0ms
# Speed: 4.3ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_30_keyframe.jpg
#
# 0: 416x640 2 persons, 3 wine glasss, 3 cups, 1 dining table, 83.1ms
# Speed: 49.1ms preprocess, 83.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_110_keyframe.jpg
#
# 0: 416x640 1 person, 76.7ms
# Speed: 3.9ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_145_keyframe.jpg
#
# 0: 416x640 1 person, 102.9ms
# Speed: 4.0ms preprocess, 102.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_62_keyframe.jpg
#
# 0: 416x640 3 persons, 1 cup, 85.5ms
# Speed: 7.4ms preprocess, 85.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_37_keyframe.jpg
#
# 0: 416x640 2 persons, 1 wine glass, 114.2ms
# Speed: 5.0ms preprocess, 114.2ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_117_keyframe.jpg
#
# 0: 416x640 3 persons, 93.7ms
# Speed: 5.3ms preprocess, 93.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_238_keyframe.jpg
#
# 0: 416x640 6 persons, 1 horse, 100.7ms
# Speed: 4.6ms preprocess, 100.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_292_keyframe.jpg
#
# 0: 416x640 (no detections), 101.2ms
# Speed: 3.8ms preprocess, 101.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_348_keyframe.jpg
#
# 0: 416x640 (no detections), 80.0ms
# Speed: 3.2ms preprocess, 80.0ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_102_keyframe.jpg
#
# 0: 416x640 2 persons, 1 horse, 81.9ms
# Speed: 5.3ms preprocess, 81.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_157_keyframe.jpg
#
# 0: 416x640 4 persons, 1 tie, 2 wine glasss, 158.6ms
# Speed: 4.7ms preprocess, 158.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_88_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 75.8ms
# Speed: 3.5ms preprocess, 75.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_77_keyframe.jpg
#
# 0: 416x640 2 persons, 1 chair, 117.4ms
# Speed: 3.3ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_22_keyframe.jpg
#
# 0: 416x640 1 person, 80.2ms
# Speed: 3.1ms preprocess, 80.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_105_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 100.0ms
# Speed: 4.1ms preprocess, 100.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_150_keyframe.jpg
#
# 0: 416x640 1 person, 1 cup, 1 chair, 88.0ms
# Speed: 3.3ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_70_keyframe.jpg
#
# 0: 416x640 2 persons, 85.3ms
# Speed: 3.8ms preprocess, 85.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_381_keyframe.jpg
#
# 0: 416x640 8 persons, 117.1ms
# Speed: 3.5ms preprocess, 117.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_209_keyframe.jpg
#
# 0: 416x640 1 person, 1 motorcycle, 1 airplane, 78.2ms
# Speed: 4.3ms preprocess, 78.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_408_keyframe.jpg
#
# 0: 416x640 6 persons, 1 horse, 67.1ms
# Speed: 3.7ms preprocess, 67.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_379_keyframe.jpg
#
# 0: 416x640 5 persons, 1 horse, 79.3ms
# Speed: 3.3ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_386_keyframe.jpg
#
# 0: 416x640 1 person, 122.0ms
# Speed: 4.7ms preprocess, 122.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_46_keyframe.jpg
#
# 0: 416x640 1 person, 79.4ms
# Speed: 3.4ms preprocess, 79.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_13_keyframe.jpg
#
# 0: 416x640 8 persons, 1 suitcase, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_133_keyframe.jpg
#
# 0: 416x640 10 persons, 75.9ms
# Speed: 4.6ms preprocess, 75.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_199_keyframe.jpg
#
# 0: 416x640 1 person, 81.7ms
# Speed: 4.6ms preprocess, 81.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_14_keyframe.jpg
#
# 0: 416x640 1 person, 71.0ms
# Speed: 4.3ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_134_keyframe.jpg
#
# 0: 416x640 1 person, 67.8ms
# Speed: 2.6ms preprocess, 67.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_161_keyframe.jpg
#
# 0: 416x640 (no detections), 68.9ms
# Speed: 2.7ms preprocess, 68.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_2_keyframe.jpg
#
# 0: 416x640 3 persons, 83.9ms
# Speed: 4.7ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_339_keyframe.jpg
#
# 0: 416x640 1 person, 2 ties, 74.9ms
# Speed: 3.4ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_393_keyframe.jpg
#
# 0: 416x640 4 persons, 124.6ms
# Speed: 3.0ms preprocess, 124.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_249_keyframe.jpg
#
# 0: 416x640 1 person, 1 tie, 157.0ms
# Speed: 5.5ms preprocess, 157.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_394_keyframe.jpg
#
# 0: 416x640 3 persons, 1 orange, 1 vase, 88.7ms
# Speed: 21.1ms preprocess, 88.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_174_keyframe.jpg
#
# 0: 416x640 6 persons, 1 tie, 1 chair, 1 clock, 88.1ms
# Speed: 2.7ms preprocess, 88.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_54_keyframe.jpg
#
# 0: 416x640 6 persons, 88.5ms
# Speed: 3.5ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_126_keyframe.jpg
#
# 0: 416x640 2 persons, 85.8ms
# Speed: 2.9ms preprocess, 85.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_173_keyframe.jpg
#
# 0: 416x640 1 person, 117.7ms
# Speed: 3.6ms preprocess, 117.7ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/DramaRecognition/Drama_05/Drama_05_Мой ласковый и нежный зверь (FullHD, драма, реж_scene_53_keyframe.jpg
# ✅ Object detection results saved to /Users/alicja/Desktop/VideoAnalyse/Corpus/KeyFrames/DramaKeyframes/object_detection_results_Drama_05.csv
# ✅ Object detection process completed!

# %% [markdown]
# ## Merging all the CSV files for every Object Recognition done on each file ##

# %%
import os
import pandas as pd



def get_folder_path(prompt):
    while True:
        path = input(prompt).strip()
        if path and os.path.exists(path):
            print(f"✅ Using folder: {path}")
            return path
        print("❌ Invalid or empty path. Please enter a valid folder path.")

csv_folder = get_folder_path("Enter the folder containing all object detection CSV files: ")
output_file = os.path.join(csv_folder, "merged_object_detection_results.csv")


csv_files = [f for f in os.listdir(csv_folder) if f.endswith(".csv")]

if not csv_files:
    print("❌ No CSV files found in the folder. Exiting.")
    exit()

print(f"📂 Found {len(csv_files)} CSV files. Merging...")

# Merge all CSV files into one dataframe
df_list = []
for csv_file in csv_files:
    file_path = os.path.join(csv_folder, csv_file)
    df = pd.read_csv(file_path)
    df["source_file"] = csv_file  # Add filename as a column
    df_list.append(df)

merged_df = pd.concat(df_list, ignore_index=True)
merged_df.to_csv(output_file, index=False)

print(f"✅ Merged dataset saved as: {output_file}")
# Out:
# ✅ Using folder: /Users/alicja/Desktop/VideoAnalyse/ObjectRecognition_Results
# 📂 Found 15 CSV files. Merging...
# ✅ Merged dataset saved as: /Users/alicja/Desktop/VideoAnalyse/ObjectRecognition_Results/merged_object_detection_results.csv

# %% [markdown]
# ## Cleaning the merged data ##
# Loads the merged dataset for analysis.
#
# Displays basic information (column names, data types, missing values)
#
# Removes duplicates to clean the data
#
#
# Saves the cleaned dataset as cleaned_object_detection_results.csv

# %%
import pandas as pd
import os



def get_file_path(prompt):
    while True:
        path = input(prompt).strip()
        if path and os.path.exists(path):
            print(f"✅ Using file: {path}")
            return path
        print("❌ Invalid or empty path. Please enter a valid file path.")

# Get the merged CSV file
csv_file = get_file_path("Enter the path to the merged object detection CSV file: ")


df = pd.read_csv(csv_file)

# Display basic info
print(" Dataset Overview:")
print(df.info())
print("\nSample Data:")
print(df.head())

# Check for missing values
missing_values = df.isnull().sum()
print("\n❗ Missing Values:")
print(missing_values[missing_values > 0])

# Remove duplicates (if any)
df = df.drop_duplicates()
print("✅ Duplicates removed.")

cleaned_file = os.path.join(os.path.dirname(csv_file), "cleaned_object_detection_results.csv")
df.to_csv(cleaned_file, index=False)
print(f"✅ Cleaned dataset saved as: {cleaned_file}")
# Out:
# ✅ Using file: /Users/alicja/Desktop/VideoAnalyse/ObjectRecognition_Results/merged_object_detection_results.csv
# 📊 Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19000 entries, 0 to 18999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image        19000 non-null  object
#  1   class        19000 non-null  object
#  2   confidence   19000 non-null  float64
#  3   bbox         19000 non-null  object
#  4   source_file  19000 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 742.3+ KB
# None
#
# 🔍 Sample Data:
#                                                image       class  confidence  \
# 0  Drama_05_Мой ласковый и нежный зверь (FullH...      person        0.80
# 1  Drama_05_Мой ласковый и нежный зверь (FullH...         tie        0.72
# 2  Drama_05_Мой ласковый и нежный зверь (FullH...  wine glass        0.33
# 3  Drama_05_Мой ласковый и нежный зверь (FullH...  wine glass        0.28
# 4  Drama_05_Мой ласковый и нежный зверь (FullH...      person        0.87
#
#                    bbox                            source_file
# 0   [149, 52, 452, 355]  object_detection_results_Drama_05.csv
# 1  [277, 193, 315, 263]  object_detection_results_Drama_05.csv
# 2  [375, 225, 403, 290]  object_detection_results_Drama_05.csv
# 3  [327, 226, 356, 280]  object_detection_results_Drama_05.csv
# 4   [131, 12, 483, 353]  object_detection_results_Drama_05.csv
#
# ❗ Missing Values:
# Series([], dtype: int64)
# ✅ Duplicates removed.
# ✅ Cleaned dataset saved as: /Users/alicja/Desktop/VideoAnalyse/ObjectRecognition_Results/cleaned_object_detection_results.csv
