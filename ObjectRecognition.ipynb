# %% [markdown]
# ## Object recognition with YOLO##

# %%
import os
import torch
import cv2
import pandas as pd
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Function to get user-defined folder paths
def get_folder_path(prompt, create_if_missing=False):
    while True:
        path = input(prompt).strip()
        if path:
            if os.path.exists(path) or create_if_missing:
                os.makedirs(path, exist_ok=True)  # Create folder if missing
                print(f"✅ Using folder: {path}")
                return path
        print("❌ Invalid or empty path. Please enter a valid folder path.")

# Function to list available folders before selection
def list_available_folders(base_path):
    print("📂 Available folders:")
    folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]
    if not folders:
        print("❌ No folders found. Exiting.")
        exit()
    for idx, folder in enumerate(folders, start=1):
        print(f"{idx}. {folder}")
    return folders

# Load YOLO model (using YOLOv8 pretrained model)
def load_yolo_model():
    print("🔄 Loading YOLOv8 model...")
    model = YOLO("yolov8n.pt")  # Using YOLOv8 Nano model (lightweight)
    print("✅ YOLO model loaded successfully!")
    return model

# Perform object detection on an image
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform detection
    detections = []
    
    for result in results:
        for box in result.boxes.data:
            x1, y1, x2, y2, conf, cls = box.tolist()
            detections.append({
                "image": os.path.basename(image_path),
                "class": model.names[int(cls)],
                "confidence": round(conf, 2),
                "bbox": [int(x1), int(y1), int(x2), int(y2)]
            })
    return detections

# Visualize detections and save annotated images
def visualize_and_save(image_path, detections, output_folder):
    image = cv2.imread(image_path)
    for det in detections:
        x1, y1, x2, y2 = det["bbox"]
        label = f"{det['class']} ({det['confidence']})"
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    output_path = os.path.join(output_folder, os.path.basename(image_path))
    cv2.imwrite(output_path, image)
    print(f"✅ Saved annotated image: {output_path}")

# Function to manually select which movies to process
def select_movies(movies):
    print("📂 Available movie folders:")
    for idx, movie in enumerate(movies, start=1):
        print(f"{idx}. {movie}")
    
    selected_indices = input("Enter the numbers of the movies you want to analyze (comma-separated, e.g., 1,3,5): ")
    selected_indices = [int(i.strip()) - 1 for i in selected_indices.split(',') if i.strip().isdigit() and 0 <= int(i.strip()) - 1 < len(movies)]
    
    if not selected_indices:
        print("❌ No valid selections made. Exiting.")
        exit()
    
    selected_movies = [movies[i] for i in selected_indices]
    return selected_movies

# Function to process all selected movies
def process_selected_movies(model, keyframe_base_folder, output_csv, output_image_folder):
    movies = list_available_folders(keyframe_base_folder)
    selected_movies = select_movies(movies)
    
    detections_list = []
    
    for movie in selected_movies:
        movie_path = os.path.join(keyframe_base_folder, movie)
        print(f"📂 Processing keyframes from movie: {movie}")
        
        keyframe_images = [f for f in os.listdir(movie_path) if f.endswith(".jpg")]
        for img in keyframe_images:
            img_path = os.path.join(movie_path, img)
            detections = detect_objects(model, img_path)
            detections_list.extend(detections)
            visualize_and_save(img_path, detections, output_image_folder)
    
    # Save detections to CSV
    df = pd.DataFrame(detections_list)
    df.to_csv(output_csv, index=False)
    print(f"✅ Object detection results saved to {output_csv}")

# Main execution
if __name__ == "__main__":
    keyframe_base_folder = get_folder_path("Enter the base folder containing movie keyframes: ")
    output_csv = os.path.join(keyframe_base_folder, "object_detection_results.csv")
    output_image_folder = get_folder_path("Enter the folder to save annotated images: ", create_if_missing=True)
    
    yolo_model = load_yolo_model()
    process_selected_movies(yolo_model, keyframe_base_folder, output_csv, output_image_folder)
    
    print("✅ Object detection process completed!")
# Out:
# ✅ Using folder: /Users/alicja/Desktop/VideoAnalyse/Corpus/KeyFrames/ActionKeyframes
# ✅ Using folder: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01
# 🔄 Loading YOLOv8 model...
# ✅ YOLO model loaded successfully!
# 📂 Available folders:
# 1. Action_01
# 2. Action_02
# 3. Action_05
# 4. Action_04
# 5. Action_03
# 📂 Available movie folders:
# 1. Action_01
# 2. Action_02
# 3. Action_05
# 4. Action_04
# 5. Action_03
# 📂 Processing keyframes from movie: Action_01
#
# 0: 384x640 (no detections), 90.9ms
# Speed: 5.0ms preprocess, 90.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_3_keyframe.jpg
#
# 0: 384x640 (no detections), 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_4_keyframe.jpg
#
# 0: 384x640 1 person, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_136_keyframe.jpg
#
# 0: 384x640 6 persons, 1 elephant, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_163_keyframe.jpg
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_131_keyframe.jpg
#
# 0: 384x640 8 persons, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_164_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_219_keyframe.jpg
#
# 0: 384x640 1 person, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_124_keyframe.jpg
#
# 0: 384x640 1 person, 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_189_keyframe.jpg
#
# 0: 384x640 7 persons, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_176_keyframe.jpg
#
# 0: 384x640 1 person, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_228_keyframe.jpg
#
# 0: 384x640 1 person, 1 traffic light, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_81_keyframe.jpg
#
# 0: 384x640 1 person, 49.3ms
# Speed: 1.4ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_115_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 75.9ms
# Speed: 1.8ms preprocess, 75.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_79_keyframe.jpg
#
# 0: 384x640 2 persons, 1 traffic light, 77.7ms
# Speed: 2.6ms preprocess, 77.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_112_keyframe.jpg
#
# 0: 384x640 (no detections), 74.2ms
# Speed: 3.7ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_107_keyframe.jpg
#
# 0: 384x640 1 person, 62.2ms
# Speed: 2.3ms preprocess, 62.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_39_keyframe.jpg
#
# 0: 384x640 3 persons, 1 bed, 67.5ms
# Speed: 1.7ms preprocess, 67.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_93_keyframe.jpg
#
# 0: 384x640 1 person, 61.5ms
# Speed: 2.1ms preprocess, 61.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_100_keyframe.jpg
#
# 0: 384x640 2 persons, 1 bird, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_155_keyframe.jpg
#
# 0: 384x640 (no detections), 77.9ms
# Speed: 2.5ms preprocess, 77.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_94_keyframe.jpg
#
# 0: 384x640 1 car, 81.9ms
# Speed: 32.1ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_218_keyframe.jpg
#
# 0: 384x640 8 persons, 1 truck, 92.2ms
# Speed: 1.8ms preprocess, 92.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_177_keyframe.jpg
#
# 0: 384x640 1 person, 68.0ms
# Speed: 2.4ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_122_keyframe.jpg
#
# 0: 384x640 2 persons, 119.5ms
# Speed: 1.7ms preprocess, 119.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_188_keyframe.jpg
#
# 0: 384x640 1 train, 60.9ms
# Speed: 1.7ms preprocess, 60.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_49_keyframe.jpg
#
# 0: 384x640 10 persons, 1 car, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_170_keyframe.jpg
#
# 0: 384x640 1 person, 1 bus, 56.7ms
# Speed: 2.4ms preprocess, 56.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_125_keyframe.jpg
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 1.6ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_5_keyframe.jpg
#
# 0: 384x640 1 clock, 61.5ms
# Speed: 1.8ms preprocess, 61.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_2_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_130_keyframe.jpg
#
# 0: 384x640 6 persons, 1 car, 59.9ms
# Speed: 1.7ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_162_keyframe.jpg
#
# 0: 384x640 (no detections), 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_137_keyframe.jpg
#
# 0: 384x640 1 person, 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_154_keyframe.jpg
#
# 0: 384x640 1 person, 61.9ms
# Speed: 1.9ms preprocess, 61.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_95_keyframe.jpg
#
# 0: 384x640 1 person, 71.0ms
# Speed: 1.6ms preprocess, 71.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_153_keyframe.jpg
#
# 0: 384x640 1 person, 71.1ms
# Speed: 1.4ms preprocess, 71.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_106_keyframe.jpg
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.8ms preprocess, 65.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_229_keyframe.jpg
#
# 0: 384x640 2 persons, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_87_keyframe.jpg
#
# 0: 384x640 1 person, 59.8ms
# Speed: 3.3ms preprocess, 59.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_78_keyframe.jpg
#
# 0: 384x640 (no detections), 58.8ms
# Speed: 1.8ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_146_keyframe.jpg
#
# 0: 384x640 1 person, 61.5ms
# Speed: 1.7ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_113_keyframe.jpg
#
# 0: 384x640 (no detections), 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_80_keyframe.jpg
#
# 0: 384x640 2 persons, 1 toilet, 70.3ms
# Speed: 1.8ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_141_keyframe.jpg
#
# 0: 384x640 1 person, 1 dog, 64.6ms
# Speed: 2.1ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_224_keyframe.jpg
#
# 0: 384x640 3 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_223_keyframe.jpg
#
# 0: 384x640 1 tv, 121.8ms
# Speed: 1.7ms preprocess, 121.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_75_keyframe.jpg
#
# 0: 384x640 1 person, 69.3ms
# Speed: 2.3ms preprocess, 69.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_20_keyframe.jpg
#
# 0: 384x640 1 person, 65.7ms
# Speed: 1.8ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_72_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 61.8ms
# Speed: 2.2ms preprocess, 61.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_27_keyframe.jpg
#
# 0: 384x640 1 person, 65.2ms
# Speed: 2.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_236_keyframe.jpg
#
# 0: 384x640 1 person, 58.7ms
# Speed: 1.8ms preprocess, 58.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_231_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 57.4ms
# Speed: 2.3ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_67_keyframe.jpg
#
# 0: 384x640 1 person, 58.9ms
# Speed: 2.2ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_32_keyframe.jpg
#
# 0: 384x640 1 person, 1 laptop, 61.0ms
# Speed: 1.4ms preprocess, 61.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_98_keyframe.jpg
#
# 0: 384x640 4 persons, 1 car, 1 truck, 2 traffic lights, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_159_keyframe.jpg
#
# 0: 384x640 1 train, 1 tv, 57.0ms
# Speed: 2.7ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_60_keyframe.jpg
#
# 0: 384x640 1 person, 61.4ms
# Speed: 1.5ms preprocess, 61.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_35_keyframe.jpg
#
# 0: 384x640 (no detections), 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_207_keyframe.jpg
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_252_keyframe.jpg
#
# 0: 384x640 4 persons, 57.9ms
# Speed: 1.6ms preprocess, 57.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_168_keyframe.jpg
#
# 0: 384x640 1 person, 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_190_keyframe.jpg
#
# 0: 384x640 1 person, 62.3ms
# Speed: 1.7ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_215_keyframe.jpg
#
# 0: 384x640 1 person, 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_240_keyframe.jpg
#
# 0: 384x640 1 car, 88.7ms
# Speed: 2.4ms preprocess, 88.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_212_keyframe.jpg
#
# 0: 384x640 1 person, 1 tie, 74.9ms
# Speed: 2.5ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_247_keyframe.jpg
#
# 0: 384x640 1 tv, 70.5ms
# Speed: 2.4ms preprocess, 70.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_44_keyframe.jpg
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 2.5ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_11_keyframe.jpg
#
# 0: 384x640 2 persons, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_16_keyframe.jpg
#
# 0: 384x640 3 persons, 123.7ms
# Speed: 2.3ms preprocess, 123.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_182_keyframe.jpg
#
# 0: 384x640 2 persons, 63.5ms
# Speed: 1.8ms preprocess, 63.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_128_keyframe.jpg
#
# 0: 384x640 1 person, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_230_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 61.2ms
# Speed: 1.8ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_237_keyframe.jpg
#
# 0: 384x640 1 person, 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_34_keyframe.jpg
#
# 0: 384x640 1 person, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_61_keyframe.jpg
#
# 0: 384x640 1 person, 1 laptop, 55.9ms
# Speed: 1.9ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_99_keyframe.jpg
#
# 0: 384x640 1 person, 57.8ms
# Speed: 1.7ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_33_keyframe.jpg
#
# 0: 384x640 9 persons, 3 trucks, 3 traffic lights, 57.0ms
# Speed: 1.4ms preprocess, 57.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_158_keyframe.jpg
#
# 0: 384x640 2 persons, 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_222_keyframe.jpg
#
# 0: 384x640 1 person, 1 tie, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_225_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 59.3ms
# Speed: 1.7ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_118_keyframe.jpg
#
# 0: 384x640 1 car, 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_26_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 73.1ms
# Speed: 1.4ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_73_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 60.4ms
# Speed: 1.6ms preprocess, 60.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_21_keyframe.jpg
#
# 0: 384x640 1 tv, 1 laptop, 67.4ms
# Speed: 1.6ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_74_keyframe.jpg
#
# 0: 384x640 2 persons, 71.1ms
# Speed: 1.9ms preprocess, 71.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_213_keyframe.jpg
#
# 0: 384x640 1 person, 74.5ms
# Speed: 2.6ms preprocess, 74.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_241_keyframe.jpg
#
# 0: 384x640 2 cars, 68.4ms
# Speed: 1.7ms preprocess, 68.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_214_keyframe.jpg
#
# 0: 384x640 1 remote, 1 keyboard, 66.6ms
# Speed: 2.8ms preprocess, 66.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_42_keyframe.jpg
#
# 0: 384x640 1 person, 70.1ms
# Speed: 2.4ms preprocess, 70.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_129_keyframe.jpg
#
# 0: 384x640 2 persons, 1 truck, 72.2ms
# Speed: 3.4ms preprocess, 72.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_183_keyframe.jpg
#
# 0: 384x640 1 person, 58.9ms
# Speed: 1.8ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_45_keyframe.jpg
#
# 0: 384x640 2 persons, 107.3ms
# Speed: 1.7ms preprocess, 107.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_184_keyframe.jpg
#
# 0: 384x640 2 persons, 63.5ms
# Speed: 1.9ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_201_keyframe.jpg
#
# 0: 384x640 (no detections), 56.1ms
# Speed: 1.7ms preprocess, 56.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_253_keyframe.jpg
#
# 0: 384x640 1 person, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_206_keyframe.jpg
#
# 0: 384x640 1 person, 59.9ms
# Speed: 1.8ms preprocess, 59.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_9_keyframe.jpg
#
# 0: 384x640 1 bear, 56.2ms
# Speed: 1.8ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_191_keyframe.jpg
#
# 0: 384x640 (no detections), 60.5ms
# Speed: 1.8ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_50_keyframe.jpg
#
# 0: 384x640 1 person, 60.4ms
# Speed: 1.8ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_196_keyframe.jpg
#
# 0: 384x640 1 cell phone, 57.4ms
# Speed: 1.8ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_57_keyframe.jpg
#
# 0: 384x640 2 persons, 4 cars, 1 tv, 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_64_keyframe.jpg
#
# 0: 384x640 1 person, 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_31_keyframe.jpg
#
# 0: 384x640 1 laptop, 1 mouse, 58.9ms
# Speed: 1.5ms preprocess, 58.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_63_keyframe.jpg
#
# 0: 384x640 1 car, 1 bus, 55.9ms
# Speed: 1.8ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_108_keyframe.jpg
#
# 0: 384x640 1 person, 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_232_keyframe.jpg
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.6ms preprocess, 58.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_89_keyframe.jpg
#
# 0: 384x640 1 person, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_71_keyframe.jpg
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 3 tvs, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_24_keyframe.jpg
#
# 0: 384x640 1 person, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_227_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 58.1ms
# Speed: 1.5ms preprocess, 58.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_220_keyframe.jpg
#
# 0: 384x640 1 clock, 57.9ms
# Speed: 1.9ms preprocess, 57.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_47_keyframe.jpg
#
# 0: 384x640 1 person, 58.2ms
# Speed: 1.7ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_12_keyframe.jpg
#
# 0: 384x640 4 persons, 2 cars, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_179_keyframe.jpg
#
# 0: 384x640 2 persons, 1 train, 57.8ms
# Speed: 1.9ms preprocess, 57.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_186_keyframe.jpg
#
# 0: 384x640 1 person, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_40_keyframe.jpg
#
# 0: 384x640 2 persons, 67.6ms
# Speed: 2.9ms preprocess, 67.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_181_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 87.1ms
# Speed: 2.2ms preprocess, 87.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_243_keyframe.jpg
#
# 0: 384x640 (no detections), 60.5ms
# Speed: 1.9ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_211_keyframe.jpg
#
# 0: 384x640 1 person, 1 tie, 63.0ms
# Speed: 1.9ms preprocess, 63.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_244_keyframe.jpg
#
# 0: 384x640 2 persons, 62.1ms
# Speed: 1.6ms preprocess, 62.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_194_keyframe.jpg
#
# 0: 384x640 1 person, 67.7ms
# Speed: 1.5ms preprocess, 67.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_55_keyframe.jpg
#
# 0: 384x640 2 persons, 67.5ms
# Speed: 3.7ms preprocess, 67.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_139_keyframe.jpg
#
# 0: 384x640 3 persons, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_193_keyframe.jpg
#
# 0: 384x640 1 person, 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_52_keyframe.jpg
#
# 0: 384x640 1 person, 57.3ms
# Speed: 1.8ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_204_keyframe.jpg
#
# 0: 384x640 2 persons, 60.8ms
# Speed: 1.9ms preprocess, 60.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_251_keyframe.jpg
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 70.8ms
# Speed: 2.6ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_70_keyframe.jpg
#
# 0: 384x640 2 persons, 1 bench, 1 bird, 1 tv, 74.6ms
# Speed: 2.1ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_149_keyframe.jpg
#
# 0: 384x640 5 persons, 6 cars, 2 trucks, 3 traffic lights, 1 microwave, 65.2ms
# Speed: 1.7ms preprocess, 65.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_22_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 1 mouse, 62.9ms
# Speed: 2.5ms preprocess, 62.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_77_keyframe.jpg
#
# 0: 384x640 4 persons, 60.0ms
# Speed: 1.8ms preprocess, 60.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_88_keyframe.jpg
#
# 0: 384x640 1 person, 58.2ms
# Speed: 1.6ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_226_keyframe.jpg
#
# 0: 384x640 1 tv, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_37_keyframe.jpg
#
# 0: 384x640 (no detections), 59.6ms
# Speed: 1.6ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_109_keyframe.jpg
#
# 0: 384x640 1 person, 64.8ms
# Speed: 1.9ms preprocess, 64.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_30_keyframe.jpg
#
# 0: 384x640 1 person, 65.4ms
# Speed: 2.2ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_65_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 111.4ms
# Speed: 2.1ms preprocess, 111.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_233_keyframe.jpg
#
# 0: 384x640 1 person, 1 tie, 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_234_keyframe.jpg
#
# 0: 384x640 1 person, 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_53_keyframe.jpg
#
# 0: 384x640 1 person, 58.7ms
# Speed: 1.7ms preprocess, 58.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_195_keyframe.jpg
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 1 tv, 1 cell phone, 56.2ms
# Speed: 1.9ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_54_keyframe.jpg
#
# 0: 384x640 1 person, 1 bus, 60.4ms
# Speed: 1.7ms preprocess, 60.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_202_keyframe.jpg
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 1.7ms preprocess, 83.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_205_keyframe.jpg
#
# 0: 384x640 1 chair, 1 couch, 61.6ms
# Speed: 2.4ms preprocess, 61.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_14_keyframe.jpg
#
# 0: 384x640 1 keyboard, 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_41_keyframe.jpg
#
# 0: 384x640 1 laptop, 56.9ms
# Speed: 2.6ms preprocess, 56.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_13_keyframe.jpg
#
# 0: 384x640 2 persons, 58.6ms
# Speed: 1.7ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_187_keyframe.jpg
#
# 0: 384x640 1 person, 60.6ms
# Speed: 2.3ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_178_keyframe.jpg
#
# 0: 384x640 1 person, 55.2ms
# Speed: 1.7ms preprocess, 55.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_245_keyframe.jpg
#
# 0: 384x640 1 person, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_210_keyframe.jpg
#
# 0: 384x640 1 person, 1 tie, 58.6ms
# Speed: 1.7ms preprocess, 58.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_242_keyframe.jpg
#
# 0: 384x640 1 car, 56.6ms
# Speed: 1.7ms preprocess, 56.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_217_keyframe.jpg
#
# 0: 384x640 4 persons, 1 car, 1 truck, 60.1ms
# Speed: 1.4ms preprocess, 60.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_127_keyframe.jpg
#
# 0: 384x640 6 persons, 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_172_keyframe.jpg
#
# 0: 384x640 (no detections), 56.3ms
# Speed: 1.6ms preprocess, 56.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_19_keyframe.jpg
#
# 0: 384x640 1 person, 3 cars, 1 bench, 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_120_keyframe.jpg
#
# 0: 384x640 6 persons, 1 dog, 1 backpack, 62.3ms
# Speed: 1.6ms preprocess, 62.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_175_keyframe.jpg
#
# 0: 384x640 1 chair, 58.0ms
# Speed: 1.3ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_248_keyframe.jpg
#
# 0: 384x640 1 person, 1 vase, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_135_keyframe.jpg
#
# 0: 384x640 (no detections), 112.6ms
# Speed: 2.1ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_132_keyframe.jpg
#
# 0: 384x640 11 persons, 1 traffic light, 2 handbags, 60.5ms
# Speed: 1.6ms preprocess, 60.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_167_keyframe.jpg
#
# 0: 384x640 (no detections), 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_198_keyframe.jpg
#
# 0: 384x640 1 person, 100.0ms
# Speed: 1.7ms preprocess, 100.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_7_keyframe.jpg
#
# 0: 384x640 1 person, 111.0ms
# Speed: 2.4ms preprocess, 111.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_151_keyframe.jpg
#
# 0: 384x640 1 person, 96.6ms
# Speed: 2.3ms preprocess, 96.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_103_keyframe.jpg
#
# 0: 384x640 1 person, 1 clock, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_156_keyframe.jpg
#
# 0: 384x640 2 persons, 2 bottles, 62.7ms
# Speed: 1.6ms preprocess, 62.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_97_keyframe.jpg
#
# 0: 384x640 1 person, 1 car, 72.8ms
# Speed: 2.1ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_239_keyframe.jpg
#
# 0: 384x640 (no detections), 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_28_keyframe.jpg
#
# 0: 384x640 1 person, 58.3ms
# Speed: 1.5ms preprocess, 58.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_116_keyframe.jpg
#
# 0: 384x640 1 person, 64.0ms
# Speed: 1.6ms preprocess, 64.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_143_keyframe.jpg
#
# 0: 384x640 1 person, 1 train, 57.4ms
# Speed: 1.6ms preprocess, 57.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_85_keyframe.jpg
#
# 0: 384x640 4 persons, 2 chairs, 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_111_keyframe.jpg
#
# 0: 384x640 2 persons, 64.5ms
# Speed: 1.9ms preprocess, 64.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_144_keyframe.jpg
#
# 0: 384x640 1 laptop, 69.6ms
# Speed: 1.9ms preprocess, 69.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_58_keyframe.jpg
#
# 0: 384x640 2 persons, 68.2ms
# Speed: 1.7ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_166_keyframe.jpg
#
# 0: 384x640 1 person, 65.4ms
# Speed: 1.6ms preprocess, 65.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_133_keyframe.jpg
#
# 0: 384x640 1 person, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_161_keyframe.jpg
#
# 0: 384x640 1 person, 64.2ms
# Speed: 2.3ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_134_keyframe.jpg
#
# 0: 384x640 1 person, 3 cars, 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_209_keyframe.jpg
#
# 0: 384x640 1 person, 70.1ms
# Speed: 1.6ms preprocess, 70.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_6_keyframe.jpg
#
# 0: 384x640 (no detections), 123.5ms
# Speed: 1.9ms preprocess, 123.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_1_keyframe.jpg
#
# 0: 384x640 1 person, 66.2ms
# Speed: 2.5ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_121_keyframe.jpg
#
# 0: 384x640 11 persons, 1 car, 58.2ms
# Speed: 1.6ms preprocess, 58.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_173_keyframe.jpg
#
# 0: 384x640 (no detections), 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_18_keyframe.jpg
#
# 0: 384x640 2 persons, 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_249_keyframe.jpg
#
# 0: 384x640 3 persons, 1 tie, 75.1ms
# Speed: 1.5ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_84_keyframe.jpg
#
# 0: 384x640 13 persons, 1 boat, 1 traffic light, 66.8ms
# Speed: 1.9ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_110_keyframe.jpg
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_29_keyframe.jpg
#
# 0: 384x640 (no detections), 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_83_keyframe.jpg
#
# 0: 384x640 1 person, 1 laptop, 59.6ms
# Speed: 1.6ms preprocess, 59.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_117_keyframe.jpg
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 1.9ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_157_keyframe.jpg
#
# 0: 384x640 1 person, 1 tv, 65.9ms
# Speed: 2.2ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_69_keyframe.jpg
#
# 0: 384x640 1 person, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_96_keyframe.jpg
#
# 0: 384x640 2 persons, 68.3ms
# Speed: 2.2ms preprocess, 68.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_150_keyframe.jpg
#
# 0: 384x640 1 person, 3 cars, 61.6ms
# Speed: 2.3ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_105_keyframe.jpg
#
# 0: 384x640 1 person, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Saved annotated image: /Users/alicja/Desktop/VideoAnalyse/Corpus/ObjectRecognition/ActionRecognition/Action_01/Action_01_RETRIBUTION｜  Action Short film_scene_91_keyframe.jpg
# ✅ Object detection results saved to /Users/alicja/Desktop/VideoAnalyse/Corpus/KeyFrames/ActionKeyframes/object_detection_results.csv
# ✅ Object detection process completed!
